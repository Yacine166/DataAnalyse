# %% [markdown]
# # This For Team NoBody Know

# %%
import pandas as pd

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn

# %%
data = pd.read_csv("data.csv", index_col=0)

# %% [markdown]
# # Showing my data base

# %%
data
# Out:
#                                                                          Address  \
# \tEmail
# mstephenson@fernandez.com             835 Frank TunnelWrightmouth, MI 82180-9605
# hduke@hotmail.com                   4547 Archer CommonDiazchester, CA 06566-8576
# pallen@yahoo.com               24645 Valerie Unions Suite 582Cobbborough, DC ...
# riverarebecca@gmail.com           1414 David ThroughwayPort Jason, OH 22070-1220
# mstephens@davidson-herman.com  14023 Rodriguez PassagePort Jacobville, PR 372...
# ...                                                                          ...
# lewisjessica@craig-evans.com   4483 Jones Motorway Suite 872Lake Jamiefurt, U...
# katrina56@gmail.com              172 Owen Divide Suite 497West Richard, CA 19320
# dale88@hotmail.com             0787 Andrews Ranch Apt. 633South Chadburgh, TN...
# cwilson@hotmail.com            680 Jennifer Lodge Apt. 808Brendachester, TX 0...
# ...

# %% [markdown]
# # Display Top 10 of My Data

# %%
data.head(10)
# Out:
#                                                                          Address  \
# \tEmail
# mstephenson@fernandez.com             835 Frank TunnelWrightmouth, MI 82180-9605
# hduke@hotmail.com                   4547 Archer CommonDiazchester, CA 06566-8576
# pallen@yahoo.com               24645 Valerie Unions Suite 582Cobbborough, DC ...
# riverarebecca@gmail.com           1414 David ThroughwayPort Jason, OH 22070-1220
# mstephens@davidson-herman.com  14023 Rodriguez PassagePort Jacobville, PR 372...
# alvareznancy@lucas.biz         645 Martha Park Apt. 611Jeffreychester, MN 672...
# katherine20@yahoo.com          68388 Reyes Lights Suite 692Josephbury, WV 922...
# awatkins@yahoo.com                           Unit 6538 Box 8980DPO AP 09026-4941
# vchurch@walter-martinez.com                 860 Lee KeyWest Debra, SD 97450-0495
# bonnie69@lin.biz                             PSC 2734, Box 5255APO AA 98456-7482
#
# ...

# %% [markdown]
# # Display Last 10 of My Data

# %%
data.tail(10)
# Out:
#                                                                         Address  \
# \tEmail
# brian28@sanchez.org               7446 Mary FerryLake Sherryfurt, GA 49066-0207
# leonardhancock@hotmail.com    64147 Alexander Station Apt. 474East Jasonview...
# davidsonkathleen@gmail.com       70128 Zimmerman OverpassRobertsshire, VA 59860
# nathan84@lowery.net           01242 Stephanie Ways Suite 003Churchville, MO ...
# kellydeborah@chan.biz             354 Sanchez Wall Suite 884Juliabury, VI 39735
# lewisjessica@craig-evans.com  4483 Jones Motorway Suite 872Lake Jamiefurt, U...
# katrina56@gmail.com             172 Owen Divide Suite 497West Richard, CA 19320
# dale88@hotmail.com            0787 Andrews Ranch Apt. 633South Chadburgh, TN...
# cwilson@hotmail.com           680 Jennifer Lodge Apt. 808Brendachester, TX 0...
# hannahwilson@davidson.com     49791 Rachel Heights Apt. 898East Drewborough,...
#
#                                       Avatar  Time on App  Time on Website  \
# ...

# %% [markdown]
# # Print information

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, mstephenson@fernandez.com to hannahwilson@davidson.com
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Address               500 non-null    object
#  1   Avatar                500 non-null    object
#  2   Time on App           500 non-null    float64
#  3   Time on Website       500 non-null    float64
#  4   Length of Membership  500 non-null    float64
#  5   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 27.3+ KB
# None

# %%
print(data.describe())
# Out:
#        Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# count   500.000000       500.000000             500.00000           500.000000
# mean     12.052620        37.060480               3.53336           499.314240
# std       0.994418         1.010555               0.99926            79.314764
# min       8.510000        33.910000               0.27000           256.670000
# 25%      11.390000        36.347500               2.93000           445.037500
# 50%      11.980000        37.070000               3.53500           498.890000
# 75%      12.752500        37.720000               4.13000           549.312500
# max      15.130000        40.010000               6.92000           765.520000

# %%
print(data.shape)
# Out:
# (500, 6)

# %% [markdown]
# # PCA

# %%
from sklearn.preprocessing import StandardScaler
values_cr = StandardScaler().fit_transform(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4124\636491345.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
# ----> 2 values_cr = StandardScaler().fit_transform(data)
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     911         # non-optimized default implementation; override when a better
#     912         # method is possible for a given clustering algorithm
#     913         if y is None:
# ...
